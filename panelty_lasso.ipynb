# %%
import pandas as pd

# %%
import sklearn

# %%
df = pd.read_csv("Boston (1).csv")
df
# Out:
#         CRIM    ZN  INDUS  CHAS     NX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS     NX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
df.sample()
# Out:
#        CRIM   ZN  INDUS  CHAS     NX     RM   AGE     DIS  RAD    TAX  \
# 24  0.75026  0.0   8.14     0  0.538  5.924  94.1  4.3996    4  307.0
#
#     PTRATIO       B  LSTAT  MEDV
# 24     21.0  394.33   16.3  15.6

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
x_sc = sc.fit_transform(x)

# %%
x_sc
# Out:
# array([[-0.41978194,  0.28482986, -1.2879095 , ..., -1.45900038,
#          0.44105193, -1.0755623 ],
#        [-0.41733926, -0.48772236, -0.59338101, ..., -0.30309415,
#          0.44105193, -0.49243937],
#        [-0.41734159, -0.48772236, -0.59338101, ..., -0.30309415,
#          0.39642699, -1.2087274 ],
#        ...,
#        [-0.41344658, -0.48772236,  0.11573841, ...,  1.17646583,
#          0.44105193, -0.98304761],
#        [-0.40776407, -0.48772236,  0.11573841, ...,  1.17646583,
#          0.4032249 , -0.86530163],
#        [-0.41500016, -0.48772236,  0.11573841, ...,  1.17646583,
#          0.44105193, -0.66905833]])

# %%
from sklearn.linear_model import Lasso

# %%
names = x.columns

# %%
names
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT'],
#       dtype='object')

# %%
def lasso(alpha):
    df1 = pd.DataFrame()  # Fix the typo here
    df1["FeatureName"] = names
    for alpha in alpha:
        lasso = Lasso(alpha=alpha)
        lasso.fit(x_sc, y)
        column_names = 'Alpha = %f' % alpha
        df1[column_names] = lasso.coef_
    return df1

lasso([0.0001, 0.001, 0.1, 0.5, 1, 10, 100])
# Out:
#    FeatureName  Alpha = 0.000100  Alpha = 0.001000  Alpha = 0.100000  \
# 0         CRIM         -0.927866         -0.925348         -0.632304
# 1           ZN          1.081086          1.076739          0.708409
# 2        INDUS          0.139960          0.131471         -0.000000
# 3         CHAS          0.681771          0.682060          0.657607
# 4           NX         -2.055877         -2.048349         -1.574193
# 5           RM          2.674402          2.675950          2.826269
# 6          AGE          0.019026          0.015049         -0.000000
# 7          DIS         -3.103667         -3.100300         -2.422079
# 8          RAD          2.660381          2.643836          1.195937
# 9          TAX         -2.074993         -2.058853         -0.846468
# 10     PTRATIO         -2.060372         -2.058263         -1.922493
# 11           B          0.849183          0.848414          0.762165
# 12       LSTAT         -3.743418         -3.741514         -3.726184
#
# ...
